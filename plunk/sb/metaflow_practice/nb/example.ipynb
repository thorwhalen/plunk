# %%
from qo import dgdisp

dgdisp("""

audio, annotations -> [segment] -> annotated_segments
""")

# %%
from qo import dgdisp

dgdisp("""
audio, annotations -> [segment] -> asegs
asegs [label="annotated segments"]
""")

# %%
dgdisp("""
data-> [selector] -> session
session -> [featurizer]-> fvs
""")
