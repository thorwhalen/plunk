# %% [markdown]
# # Incremental Classification

# %%
from sklearn.datasets import make_blobs
X,y=make_blobs(shuffle=True,centers=2,n_samples=2000)

# %%
y[:10]
# Out:
# array([1, 0, 0, 1, 0, 1, 0, 1, 1, 0])

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0], X[:,1], c=y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
# array([[-1.2757889 , -2.06833337],
#        [ 5.75806262, 10.2728482 ],
#        [-1.64025937, -4.76847902],
#        ...,
#        [-2.40702043, -2.32640974],
#        [-0.3974434 , -3.75747419],
#        [-1.0650655 , -3.9163885 ]])

# %%
from river import linear_model

model=linear_model.LogisticRegression()

for x_i,y_i in zip(X_train,y_train):  
    x_json = {'val1': x_i[0], 'val2': x_i[1]}
    #print(x_json, y_i)
    model.learn_one(x_json,y_i)

# %%
import pandas as pd
preds = model.predict_many(pd.DataFrame(X_test,columns=['val1', 'val2']))

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, preds)
# Out:
# 1.0

# %% [markdown]
# # On clicks

# %%
import os
import pandas as pd
path = '/Users/sylvain/Dropbox/Otosense/AutomotiveClick'
fname = 'DataSet.csv'
df = pd.read_csv(os.path.join(path, fname))

# %%
df.head()
# Out:
#            1         2         3         4         5         6         7  \
# 0 -13.662306 -1.213956  0.091993  0.676190  1.312613  0.027688 -0.747415
# 1 -11.526928 -6.211858  2.750044 -0.061428  0.429221  0.300266 -1.389557
# 2 -13.206510 -2.321447 -1.979495  0.375425  1.352997 -0.200878 -0.591294
# 3 -13.463289 -2.677057 -0.494886 -0.085733  0.577429 -0.974396 -0.477510
# 4 -11.070806 -6.937875  0.040004 -0.424837  0.013395 -0.400774 -1.299304
#
#           8         9        10  ...       205       206       207       208  \
# 0 -1.608924 -0.838222 -1.502929  ...  1.381945  1.283971  1.618763  0.033949
# 1 -1.279078 -1.578858 -1.438394  ...  1.523271  1.864626  2.073151  0.030179
# 2 -1.589053 -0.402575 -0.996716  ...  1.595854  1.691437  1.749022  0.042193
# 3 -0.916750 -0.651306 -1.036478  ...  1.588836  1.589482  1.641766  0.067129
# 4 -1.363103 -0.639002 -1.866900  ...  1.625993  1.914830  2.053987  0.031203
#
#         209       210       211       212       213  Class
# 0  0.036194  0.029503  0.034059  0.034227  0.034765      0
# 1  0.031628  0.031147  0.025628  0.034281  0.029865      1
# 2  0.042270  0.043961  0.043115  0.044511  0.043367      0
# 3  0.064051  0.059113  0.061009  0.064148  0.065584      0
# 4  0.030602  0.028771  0.032160  0.031300  0.030377      0
#
# [5 rows x 214 columns]

# %%
df[['1','2','3']].plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
from hum import disp_wf, plot_wf

plot_wf(df['1'])

# %%
disp_wf(df['1'])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from river import synth

# %%
synth.
# Out:
# <module 'river.datasets.synth' from '/Users/sylvain/opt/anaconda3/envs/otopy38/lib/python3.8/site-packages/river/datasets/synth/__init__.py'>
